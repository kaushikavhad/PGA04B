# %%
credit_data_sample<- read.csv("M:\\Imarticus\\ProjectR\\Credit card fraud\\Datafiles\\credit_data_sample.csv", header = TRUE,
                       stringsAsFactors = TRUE,
                       strip.white = FALSE ,
                       sep = ',')

# %%
credit_data_sample<- credit_data_sample[,1:30]
pca_credit<- prcomp(credit_data_sample, center = TRUE,scale = TRUE)
summary(pca_credit)
# Out:
# Importance of components:
#                          PC1     PC2    PC3    PC4     PC5     PC6     PC7
# Standard deviation     3.295 1.57165 1.3539 1.2099 1.17246 1.12055 1.08904
# Proportion of Variance 0.362 0.08234 0.0611 0.0488 0.04582 0.04185 0.03953
# Cumulative Proportion  0.362 0.44431 0.5054 0.5542 0.60003 0.64188 0.68142
#                            PC8     PC9    PC10   PC11   PC12    PC13   PC14
# Standard deviation     1.02387 0.98841 0.93990 0.9198 0.9017 0.85692 0.7861
# Proportion of Variance 0.03494 0.03257 0.02945 0.0282 0.0271 0.02448 0.0206
# Cumulative Proportion  0.71636 0.74893 0.77837 0.8066 0.8337 0.85815 0.8788
#                           PC15    PC16    PC17    PC18    PC19    PC20    PC21
# Standard deviation     0.75087 0.69680 0.67336 0.63703 0.57604 0.51762 0.48816
# Proportion of Variance 0.01879 0.01618 0.01511 0.01353 0.01106 0.00893 0.00794
# Cumulative Proportion  0.89755 0.91373 0.92885 0.94237 0.95343 0.96236 0.97031
# ...

# %%
library("factoextra")
fviz_cos2(pca_credit, choice = "var", axes = 1:2)
# Out:
# plot without title

# %%
fviz_contrib(pca_credit, choice = "var", axes = 1, top = 5)
# Out:
# plot without title

# %%
fviz_contrib(pca_credit, choice = "var", axes = 2, top = 5)
biplot(pca_credit,scale=0)
# Out:
# plot without title
# plot without title
